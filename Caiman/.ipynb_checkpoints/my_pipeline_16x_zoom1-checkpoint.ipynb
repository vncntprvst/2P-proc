# %% [markdown]
# <html><head><meta content="text/html; charset=UTF-8" http-equiv="content-type"><style type="text/css">ol</style></head><body class="c5"><p class="c0 c4"><span class="c3"></span></p><p class="c2 title" id="h.rrbabt268i6e"><h1>CaImAn&rsquo;s Demo pipeline</h1></p><p class="c0"><span class="c3">This notebook will help to demonstrate the process of CaImAn and how it uses different functions to denoise, deconvolve and demix neurons from a two-photon Calcium Imaging dataset. The demo shows how to construct the `params`, `MotionCorrect` and `cnmf` objects and call the relevant functions. You can also run a large part of the pipeline with a single method (`cnmf.fit_file`). See inside for details.
#
# Dataset couresy of Sue Ann Koay and David Tank (Princeton University)
#
# This demo pertains to two photon data. For a complete analysis pipeline for one photon microendoscopic data see demo_pipeline_cnmfE.ipynb</span></p>
# <p class="c0"><span class="c3">More information can be found in the companion paper. </span></p>
# </html>

# %%
import bokeh.plotting as bpl
import cv2
import glob
import logging
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy.io
import tifffile

try:
    cv2.setNumThreads(0)
except():
    pass

try:
    if __IPYTHON__:
        # this is used for debugging purposes only. allows to reload classes
        # when changed
        get_ipython().magic('load_ext autoreload')
        get_ipython().magic('autoreload 2')
except NameError:
    pass

import caiman as cm
from caiman.motion_correction import MotionCorrect
from caiman.source_extraction.cnmf import cnmf as cnmf
from caiman.source_extraction.cnmf import params as params
from caiman.utils.utils import download_demo
from caiman.utils.visualization import plot_contours, nb_view_patches, nb_plot_contour
bpl.output_notebook()

# %% [markdown]
# ### Set up logger (optional)
# You can log to a file using the filename parameter, or make the output more or less verbose by setting level to `logging.DEBUG`, `logging.INFO`, `logging.WARNING`, or `logging.ERROR`. A filename argument can also be passed to store the log file

# %%
logging.basicConfig(format=
                          "%(relativeCreated)12d [%(filename)s:%(funcName)20s():%(lineno)s] [%(process)d] %(message)s",
                    # filename="/tmp/caiman.log",
                    level=logging.WARNING)

# %% [markdown]
# ### Link single tiff to multipage tiff (optional)
# You can chain tiff images from a single run or from multiple runs if the same ROI was imaged multiple times.

# %%
chain_tiff = True
savedir = 'D:\\Analysis\\2P\\VG1GC6_G1M0\\06302022\\run6to10\\'

if chain_tiff:
    sourcedir1 = 'D:\\Data\\2P\\VG1GC6_G1M0\\06302022\\TSeries-06302022-1009-006'
    sourcedir2 = 'D:\\Data\\2P\\VG1GC6_G1M0\\06302022\\TSeries-06302022-1009-007'
    sourcedir3 = 'D:\\Data\\2P\\VG1GC6_G1M0\\06302022\\TSeries-06302022-1009-008'
    sourcedir4 = 'D:\\Data\\2P\\VG1GC6_G1M0\\06302022\\TSeries-06302022-1009-009'
    sourcedir5 = 'D:\\Data\\2P\\VG1GC6_G1M0\\06302022\\TSeries-06302022-1009-010'
  #  sourcedir6 = 'D:\\Data\\2P\\VG1GC6_G1M0\\04282022\\TSeries-04282022-1450-006'

    fls = [glob.glob(os.path.join(sourcedir1,'*_Ch2_*.ome.tif')),
       glob.glob(os.path.join(sourcedir2,'*_Ch2_*.ome.tif')),
       glob.glob(os.path.join(sourcedir3,'*_Ch2_*.ome.tif')),
       glob.glob(os.path.join(sourcedir4,'*_Ch2_*.ome.tif')),
       glob.glob(os.path.join(sourcedir5,'*_Ch2_*.ome.tif'))]
    #   glob.glob(os.path.join(sourcedir6,'*_Ch2_*.ome.tif'))]

    fls.sort()  # make sure your files are sorted alphanumerically

    m = cm.load_movie_chain(fls,outtype=np.ushort)

    m.save(os.path.join(savedir,'data.h5'),to32=False)
# Out:
#        10346 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10347 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10350 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10350 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10353 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10353 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10356 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10356 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10359 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10359 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10362 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10362 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10365 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10366 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10368 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10369 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10371 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10372 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10374 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10375 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10377 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10378 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10381 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10382 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10384 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10385 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10387 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10388 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10390 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10393 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10395 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10396 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10399 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10399 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10402 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10402 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10405 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10405 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10408 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10408 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10411 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10412 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10414 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10415 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10417 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10418 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10420 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10421 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10423 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10424 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#   7%|█████▍                                                                         | 93/1350 [00:00<00:04, 305.27it/s]       10428 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10429 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10431 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10432 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10434 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10435 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10437 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10438 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10441 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10441 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10444 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10444 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10447 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10448 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10450 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10451 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10453 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10454 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10456 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10457 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10460 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10460 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10463 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10463 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10466 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10466 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10469 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10469 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10472 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10472 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10475 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10476 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10479 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10479 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10482 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10482 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10485 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10485 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10488 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10489 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10491 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10492 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10495 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10495 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10498 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10498 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10501 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10502 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10504 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10505 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10508 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10508 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10511 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10511 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10514 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10514 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10517 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10517 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10521 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10521 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10524 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10524 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10527 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10527 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#   9%|███████▏                                                                      | 125/1350 [00:00<00:03, 307.42it/s]       10531 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10532 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10534 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10535 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10537 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10538 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10541 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10541 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10544 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10545 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10547 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10548 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10550 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10551 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10553 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10554 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10556 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10557 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10560 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10560 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10563 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10563 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10566 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10567 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10569 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10570 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10573 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10573 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10576 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10576 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10579 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10579 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10582 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10582 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10585 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10586 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10588 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10589 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10591 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10592 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10595 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10595 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10598 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10598 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10601 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10601 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10604 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10604 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10607 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10608 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10610 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10611 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10613 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10614 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10617 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10618 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10621 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10621 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10624 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10624 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10627 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10627 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#  12%|█████████                                                                     | 156/1350 [00:00<00:03, 308.34it/s]       10631 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10632 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10635 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10636 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10638 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10639 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10641 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10642 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10644 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10645 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10647 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10648 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10650 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10651 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10653 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10654 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10656 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10657 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10659 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10660 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10663 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10663 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10666 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10667 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10669 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10670 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10672 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10673 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10676 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10676 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10679 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10679 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10682 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10683 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10685 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10686 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10688 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10689 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10692 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10692 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10695 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10695 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10698 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10698 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10701 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10701 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10704 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10705 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10707 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10708 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10710 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10711 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10713 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10714 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10716 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10717 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10719 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10720 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10723 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10723 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10726 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10726 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10729 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10730 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#  14%|██████████▊                                                                   | 188/1350 [00:00<00:03, 309.14it/s]       10734 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10734 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10737 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10738 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10740 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10741 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10744 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10744 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10747 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10747 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10750 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10751 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10753 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10754 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10756 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10757 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10760 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10760 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10763 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10763 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10766 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10766 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10769 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10770 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10773 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10773 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10776 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10776 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10779 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10780 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10782 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10783 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10785 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10786 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10788 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10789 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10792 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10792 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10795 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10795 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10798 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10798 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10801 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10801 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10804 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10805 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10807 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10808 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10810 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10811 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10813 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10814 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10817 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10817 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10820 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10820 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10823 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10823 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10826 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10827 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10829 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10830 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#  16%|████████████▋                                                                 | 219/1350 [00:00<00:03, 309.42it/s]       10834 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10835 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10837 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10838 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10840 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10841 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10843 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10844 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10847 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10847 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10850 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10850 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10853 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10853 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10856 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10856 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10859 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10860 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10862 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10863 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10865 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10866 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10869 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10869 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10872 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10872 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10875 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10876 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10879 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10879 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10882 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10882 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10885 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10885 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10888 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10889 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10891 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10892 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10894 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10895 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10897 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10898 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10901 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10901 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10904 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10904 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10907 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10907 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10910 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10910 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10913 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10914 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10916 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10917 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10919 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10920 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10922 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10923 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10926 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10926 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10929 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10929 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10932 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10933 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#  19%|██████████████▌                                                               | 251/1350 [00:00<00:03, 310.80it/s]       10936 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10937 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10939 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10940 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10943 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10943 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10946 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10947 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10950 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10950 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10953 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10953 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10956 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10956 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10959 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10959 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10962 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10963 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10965 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10966 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10969 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10969 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10972 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10973 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10976 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10976 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10979 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10979 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10982 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10982 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10985 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10986 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10988 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10989 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10991 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10992 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10995 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10995 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        10998 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        10998 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        11001 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
# ...
#        34478 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34481 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34481 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34484 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34484 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34487 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34487 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34490 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34490 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34493 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34493 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34496 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34496 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#  96%|█████████████████████████████████████████████████████████████████████████▌   | 1290/1350 [00:04<00:00, 312.00it/s]       34500 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34501 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34503 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34504 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34507 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34507 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34510 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34510 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34513 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34514 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34516 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34517 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34519 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34520 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34522 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34523 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34525 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34526 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34528 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34529 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34532 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34532 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34535 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34535 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34538 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34539 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34541 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34542 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34544 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34545 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34548 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34548 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34551 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34551 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34554 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34554 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34557 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34557 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34560 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34560 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34563 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34563 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34566 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34566 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34569 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34570 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34572 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34573 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34575 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34576 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34579 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34579 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34582 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34582 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34585 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34586 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34588 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34589 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34591 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34592 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34594 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34595 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34598 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34598 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#
#  98%|███████████████████████████████████████████████████████████████████████████▍ | 1322/1350 [00:04<00:00, 312.52it/s]       34602 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34602 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34605 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34606 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34608 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34609 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34611 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34612 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34614 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34615 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34617 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34618 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34621 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34621 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34624 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34624 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34627 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34627 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34630 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34631 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34633 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34634 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34637 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34637 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34640 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34641 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34643 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34644 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34646 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34647 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34649 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34650 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34652 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34653 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34655 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34656 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34659 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34659 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34662 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34662 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34665 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34665 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34668 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34669 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34672 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34672 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34675 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34675 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34678 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34678 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34681 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34682 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34685 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34685 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
#        34688 [tifffile.py:         log_warning():16549] [664] OME series: not an ome-tiff master file
#        34689 [movies.py:                load():1515] [664] Your tif file is saved a single pagefile. Performance will be affected
# 100%|█████████████████████████████████████████████████████████████████████████████| 1350/1350 [00:04<00:00, 314.25it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:25<00:00,  5.08s/it]
#        83746 [timeseries.py:                save():278] [664] No file saved

# %% [markdown]
# ### Select file(s) to be processed
# The `download_demo` function will download the specific file for you and return the complete path to the file which will be stored in your `caiman_data` directory. If you adapt this demo for your data make sure to pass the complete path to your file(s). Remember to pass the `fname` variable as a list.

# %%
fnames = [savedir + 'data.h5']  # filename to be processed
#if fnames[0] in ['data.tif', 'demoMovie.tif']:
#    fnames = [download_demo(fnames[0])]

# %% [markdown]
# ### Play the movie (optional)
# Play the movie (optional). This will require loading the movie in memory which in general is not needed by the pipeline. Displaying the movie uses the OpenCV library. Press `q` to close the video panel.

# %%
m_orig = cm.load_movie_chain(fnames)
display_movie = False
if display_movie:    
    ds_ratio = 1
    m_orig.resize(1, 1, ds_ratio).play(
        q_max=99.5, fr=7.5, magnification=1)

# %% [markdown]
# ### Setup some parameters
# We set some parameters that are relevant to the file, and then parameters for motion correction, processing with CNMF and component quality evaluation. Note that the dataset `Sue_2x_3000_40_-46.tif` has been spatially downsampled by a factor of 2 and has a lower than usual spatial resolution (2um/pixel). As a result several parameters (`gSig, strides, max_shifts, rf, stride_cnmf`) have lower values (halved compared to a dataset with spatial resolution 1um/pixel).

# %%
# load params or save them if they do not exist

save_params = True

if save_params:    
   
    # dataset dependent parameters
    fr = 15                             # imaging rate in frames per second
    decay_time = 1.2                    # length of a typical transient in seconds
    stim_seq = (1200,100,100,100,70)         # stim intensity values
    stim_left_side = 1
    Ntrial = 15                         
    trial_duration = 6                  # in s
    stim_delay = 2                      # in s
    Npixel_x = 1024
    Npixel_y = 1024
    objective ='16x'
    numerical_zoom = 1
    behavior_run_names = ['run6','run7','run8','run9','run10']
 
    # 16x zoom1 1024x1024
    #motion correction parameters
    strides = (100, 100)          # start a new patch for pw-rigid motion correction every x pixels
    overlaps = (50, 50)         # overlap between pathes (size of patch strides+overlaps)
    max_shifts = (40,40)        # maximum allowed rigid shifts (in pixels)
    max_deviation_rigid = 20     # maximum shifts deviation allowed for patch with respect to rigid shifts
    pw_rigid = True             # flag for performing non-rigid motion correction

    # parameters for source extraction and deconvolution
    p = 1                       # order of the autoregressive system
    gnb = 2                     # number of global background components
    merge_thr = 0.85             # merging threshold, max correlation allowed
    rf = 25                     # half-size of the patches in pixels. e.g., if rf=25, patches are 50x50
    stride_cnmf = 10             # amount of overlap between the patches in pixels
    K = 8                       # number of components per patch
    gSig = [5, 5]               # expected half size of neurons in pixels
    method_init = 'greedy_roi'  # initialization method (if analyzing dendritic data using 'sparse_nmf')
    ssub = 1                    # spatial subsampling during initialization
    tsub = 1                    # temporal subsampling during intialization

    # 16x zoom1 512x512
    # motion correction parameters
#    strides = (80, 80)          # start a new patch for pw-rigid motion correction every x pixels
#    overlaps = (40, 40)         # overlap between pathes (size of patch strides+overlaps)
#    max_shifts = (16, 16)        # maximum allowed rigid shifts (in pixels)
#    max_deviation_rigid = 8     # maximum shifts deviation allowed for patch with respect to rigid shifts
#    pw_rigid = True             # flag for performing non-rigid motion correction

    # parameters for source extraction and deconvolution
#    p = 1                       # order of the autoregressive system
#    gnb = 2                     # number of global background components
#    merge_thr = 0.75             # merging threshold, max correlation allowed
#    rf = 18                     # half-size of the patches in pixels. e.g., if rf=25, patches are 50x50
#    stride_cnmf = 8             # amount of overlap between the patches in pixels
#    K = 10                       # number of components per patch
#    gSig = [4, 4]               # expected half size of neurons in pixels
#    method_init = 'greedy_roi'  # initialization method (if analyzing dendritic data using 'sparse_nmf')
#    ssub = 1                    # spatial subsampling during initialization
#    tsub = 1                    # temporal subsampling during intialization
   
    # parameters for component evaluation
    SNR_lowest = 1.5
    min_SNR = 2.5              # signal to noise ratio for accepting a component
    rval_lowest = 0.4
    rval_thr = 0.85              # space correlation threshold for accepting a component
    cnn_thr = 0.95              # threshold for CNN based classifier
    cnn_lowest = 0.2            # neurons with cnn probability lower than this value are rejected
    
    # save params to matlab
    scipy.io.savemat(savedir + 'params.mat', mdict={'fr': fr,
                                                    'decay_time': decay_time,
                                                    'stim_seq': stim_seq,
                                                    'stim_left_side': stim_left_side,
                                                    'Ntrial': Ntrial,
                                                    'trial_duration': trial_duration,
                                                    'stim_delay': stim_delay,
                                                    'Npixel_x': Npixel_x,
                                                    'Npixel_y': Npixel_y,
                                                    'objective': objective,
                                                    'numerical_zoom': numerical_zoom,
                                                    'behavior_run_names': behavior_run_names,
                                                    'strides': strides,
                                                    'overlaps': overlaps,
                                                    'max_shifts': max_shifts,
                                                    'max_deviation_rigid': max_deviation_rigid,
                                                    'pw_rigid': pw_rigid,
                                                    'p': p,
                                                    'gnb': gnb,
                                                    'merge_thr': merge_thr,
                                                    'rf': rf,
                                                    'stride_cnmf': stride_cnmf,
                                                    'K': K,
                                                    'gSig': gSig,
                                                    'method_init': method_init,
                                                    'ssub': ssub,
                                                    'tsub': tsub,
                                                    'min_SNR': min_SNR,
                                                    'SNR_lowest': SNR_lowest,
                                                    'rval_thr': rval_thr,
                                                    'rval_lowest': rval_lowest,
                                                    'cnn_thr': cnn_thr,
                                                    'cnn_lowest': cnn_lowest})
else:
    myparams = scipy.io.loadmat(savedir + 'params.mat',squeeze_me=True)
   
    fr = myparams['fr']                    
    decay_time = myparams['decay_time'] 
    stim_seq = myparams['stim_seq'] 
    stim_left_side = myparams['stim_left_side']
    Ntrial = myparams['Ntrial']                          
    trial_duration = myparams['trial_duration'] 
    stim_delay = myparams['stim_delay'] 
    Npixel_x = myparams['Npixel_x']
    Npixel_y = myparams['Npixel_y']
    objective =myparams['objective']
    numerical_zoom = myparams['numerical_zoom']
    behavior_run_names = myparams['behavior_run_names']
   
    strides = myparams['strides'] 
    overlaps = myparams['overlaps'] 
    max_shifts = myparams['max_shifts'] 
    max_deviation_rigid = myparams['max_deviation_rigid']
    pw_rigid = True

    # parameters for source extraction and deconvolution
    p = myparams['p'] 
    gnb = myparams['gnb'] 
    merge_thr = myparams['merge_thr'] 
    rf = myparams['rf'] 
    stride_cnmf = myparams['stride_cnmf'] 
    K = myparams['K'] 
    gSig = myparams['gSig'] 
    method_init = myparams['method_init'] 
    ssub = myparams['ssub'] 
    tsub = myparams['tsub'] 

    # parameters for component evaluation
    min_SNR = myparams['min_SNR'] 
    SNR_lowest = myparams['SNR_lowest']
    rval_thr = myparams['rval_thr'] 
    rval_lowest = myparams['rval_lowest']
    cnn_thr = myparams['cnn_thr'] 
    cnn_lowest = myparams['cnn_lowest']

# %% [markdown]
# ### Create a parameters object
# You can creating a parameters object by passing all the parameters as a single dictionary. Parameters not defined in the dictionary will assume their default values. The resulting `params` object is a collection of subdictionaries pertaining to the dataset to be analyzed `(params.data)`, motion correction `(params.motion)`, data pre-processing `(params.preprocess)`, initialization `(params.init)`, patch processing `(params.patch)`, spatial and temporal component `(params.spatial), (params.temporal)`, quality evaluation `(params.quality)` and online processing `(params.online)`

# %%
opts_dict = {'fnames': fnames,
            'fr': fr,
            'decay_time': decay_time,
            'strides': strides,
            'overlaps': overlaps,
            'max_shifts': max_shifts,
            'max_deviation_rigid': max_deviation_rigid,
            'pw_rigid': pw_rigid,
            'p': p,
            'nb': gnb,
            'rf': rf,
            'gSig': gSig, 
            'K': K, 
            'stride': stride_cnmf,
            'method_init': method_init,
            'rolling_sum': True,
            'only_init': True,
            'ssub': ssub,
            'tsub': tsub,
            'merge_thr': merge_thr, 
            'min_SNR': min_SNR,
            'SNR_lowest': SNR_lowest,
            'rval_thr': rval_thr,
            'rval_lowest': rval_lowest,
            'use_cnn': True,
            'min_cnn_thr': cnn_thr,
            'cnn_lowest': cnn_lowest}

opts = params.CNMFParams(params_dict=opts_dict)

# %% [markdown]
# ### Setup a cluster
# To enable parallel processing a (local) cluster needs to be set up. This is done with a cell below. The variable `backend` determines the type of cluster used. The default value `'local'` uses the multiprocessing package. The `ipyparallel` option is also available. More information on these choices can be found [here](https://github.com/flatironinstitute/CaImAn/blob/master/CLUSTER.md). The resulting variable `dview` expresses the cluster option. If you use `dview=dview` in the downstream analysis then parallel processing will be used. If you use `dview=None` then no parallel processing will be employed.

# %%
#%% start a cluster for parallel processing (if a cluster already exists it will be closed and a new session will be opened)
if 'dview' in locals():
    cm.stop_server(dview=dview)
c, dview, n_processes = cm.cluster.setup_cluster(
    backend='local', n_processes=None, single_thread=False)

# %% [markdown]
# ## Motion Correction
# First we create a motion correction object with the parameters specified. Note that the file is not loaded in memory

# %%
# first we create a motion correction object with the parameters specified
mc = MotionCorrect(fnames, dview=dview, **opts.get_group('motion'))
# note that the file is not loaded in memory

# %% [markdown]
# Now perform motion correction. From the movie above we see that the dateset exhibits non-uniform motion. We will perform piecewise rigid motion correction using the NoRMCorre algorithm. This has already been selected by setting `pw_rigid=True` when defining the parameters object.

# %%
# %%capture
#%% Run piecewise-rigid motion correction using NoRMCorre
mc.motion_correct(save_movie=True)
m_els = cm.load(mc.fname_tot_els)
border_to_0 = 0 if mc.border_nan is 'copy' else mc.border_to_0 
    # maximum shift to be used for trimming against NaNs

# %% [markdown]
# Inspect the results by comparing the original movie. A more detailed presentation of the motion correction method can be found in the [demo motion correction](./demo_motion_correction.ipynb) notebook.

# %%
#%% compare with original movie
mean_map_raw = np.mean(m_orig,0)
mean_map_motion_corrected = np.mean(m_els,0)
corr_map_raw = m_orig.local_correlations(eight_neighbours=True, swap_dim=False)
corr_map_motion_corrected = m_els.local_correlations(eight_neighbours=True, swap_dim=False)
plt.figure(figsize = (20,20))
plt.subplot(2,2,1); plt.imshow(mean_map_raw)
plt.subplot(2,2,2); plt.imshow(mean_map_motion_corrected)
plt.subplot(2,2,3); plt.imshow(corr_map_raw)
plt.subplot(2,2,4); plt.imshow(corr_map_motion_corrected)

display_movie = False
if display_movie:
    m_orig = cm.load_movie_chain(fnames)
    ds_ratio = 1
    cm.concatenate([m_orig.resize(1, 1, ds_ratio) - mc.min_mov*mc.nonneg_movie,
                    m_els.resize(1, 1, ds_ratio)], 
                   axis=2).play(fr=30, gain=1, magnification=1, offset=0)  # press q to exit
    
# save motion corrected movie
m_els.save(savedir + 'data_motion_corrected.tif')

# %%
#%% plot rigid shifts
plt.close()
plt.figure(figsize = (20,10))
plt.plot(mc.shifts_rig)
plt.legend(['x shifts','y shifts'])
plt.xlabel('frames')
plt.ylabel('pixels')

# %% [markdown]
# ## Memory mapping
#
# The cell below memory maps the file in order `'C'` and then loads the new memory mapped file. The saved files from motion correction are memory mapped files stored in `'F'` order. Their paths are stored in `mc.mmap_file`.

# %%
#%% MEMORY MAPPING
# memory map the file in order 'C'
fname_new = cm.save_memmap(mc.mmap_file, base_name='memmap_', order='C',
                           border_to_0=border_to_0, dview=dview) # exclude borders

# now load the file
Yr, dims, T = cm.load_memmap(fname_new)
images = np.reshape(Yr.T, [T] + list(dims), order='F') 
    #load frames in python format (T x X x Y)

# %% [markdown]
# Now restart the cluster to clean up memory

# %%
#%% restart cluster to clean up memory
cm.stop_server(dview=dview)
c, dview, n_processes = cm.cluster.setup_cluster(
    backend='local', n_processes=None, single_thread=False)

# %% [markdown]
# ## Run CNMF on patches in parallel
#
# - The FOV is split is different overlapping patches that are subsequently processed in parallel by the CNMF algorithm.
# - The results from all the patches are merged with special attention to idendtified components on the border.
# - The results are then refined by additional CNMF iterations.

# %%
# %%capture
#%% RUN CNMF ON PATCHES
# First extract spatial and temporal components on patches and combine them
# for this step deconvolution is turned off (p=0). If you want to have
# deconvolution within each patch change params.patch['p_patch'] to a
# nonzero value
cnm = cnmf.CNMF(n_processes, params=opts, dview=dview)
cnm = cnm.fit(images)

# %% [markdown]
# ## Run the entire pipeline up to this point with one command
# It is possible to run the combined steps of motion correction, memory mapping, and cnmf fitting in one step as shown below. The command is commented out since the analysis has already been performed. It is recommended that you familiriaze yourself with the various steps and the results of the various steps before using it.

# %%
#cnm1 = cnmf.CNMF(n_processes, params=opts, dview=dview)
#cnm1.fit_file(motion_correct=True)

# %% [markdown]
# ### Inspecting the results
# Briefly inspect the results by plotting contours of identified components against correlation image.
# The results of the algorithm are stored in the object `cnm.estimates`. More information can be found in the definition of the `estimates` object and in the [wiki](https://github.com/flatironinstitute/CaImAn/wiki/Interpreting-Results).

# %%
#%% plot contours of found components
Cn = cm.local_correlations(images.transpose(1,2,0))
Cn[np.isnan(Cn)] = 0
cnm.estimates.plot_contours_nb(img=Cn)

# %% [markdown]
# ## Re-run (seeded) CNMF  on the full Field of View
# You can re-run the CNMF algorithm seeded on just the selected components from the previous step. Be careful, because components rejected on the previous step will not be recovered here.

# %%
# %%capture
#%% RE-RUN seeded CNMF on accepted patches to refine and perform deconvolution 
cnm2 = cnm.refit(images, dview=dview)

# %% [markdown]
# ## Component Evaluation
#
# The processing in patches creates several spurious components. These are filtered out by evaluating each component using three different criteria:
#
# - the shape of each component must be correlated with the data at the corresponding location within the FOV
# - a minimum peak SNR is required over the length of a transient
# - each shape passes a CNN based classifier

# %%
#%% COMPONENT EVALUATION
# the components are evaluated in three ways:
#   a) the shape of each component must be correlated with the data
#   b) a minimum peak SNR is required over the length of a transient
#   c) each shape passes a CNN based classifier

cnm2.estimates.evaluate_components(images, cnm2.params, dview=dview)

# %% [markdown]
# Plot contours of selected and rejected components

# %%
#%% PLOT COMPONENTS
cnm2.estimates.plot_contours_nb(img=Cn, idx=cnm2.estimates.idx_components)

# %% [markdown]
# View traces of accepted and rejected components. Note that if you get data rate error you can start Jupyter notebooks using:
# 'jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10'

# %%
# accepted components
cnm2.estimates.nb_view_components(img=Cn, idx=cnm2.estimates.idx_components[1:1000])

# %%
# rejected components
if len(cnm2.estimates.idx_components_bad) > 0:
    cnm2.estimates.nb_view_components(img=Cn, idx=cnm2.estimates.idx_components_bad[1:2])
else:
    print("No components were rejected.")

# %% [markdown]
# ### Extract DF/F values

# %%
#%% Extract DF/F values
cnm2.estimates.detrend_df_f(quantileMin=15, frames_window=1800)

# %% [markdown]
# ### Select only high quality components

# %%
cnm2.estimates.select_components(use_object=True)

# %% [markdown]
# ## Display final results

# %%
cnm2.estimates.nb_view_components(img=Cn, denoised_color='red',idx=range(1,500))
print('you may need to change the data rate to generate this one: use jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10 before opening jupyter notebook')

# %% [markdown]
# ## Deconvolved dff

# %%
cnm2.estimates.deconvolve(params=opts,dview=None, dff_flag=True)

# %% [markdown]
# ### Save to Matlab

# %%
# save results for matlab
scipy.io.savemat(savedir + 'results_caiman.mat', mdict={'mean_map_raw': mean_map_raw,
                                                 'mean_map_motion_corrected': mean_map_motion_corrected,
                                                 'corr_map_raw': corr_map_raw,
                                                 'corr_map_motion_corrected': corr_map_motion_corrected,
                                                 'spatial_components': cnm2.estimates.A,
                                                 'temporal_components': cnm2.estimates.C,
                                                 'background_spatial_component': cnm2.estimates.b,
                                                 'background_temporal_component': cnm2.estimates.f,
                                                 'df_wo_bckgrnd': cnm2.estimates.F_dff,
                                                 'deconv_spk': cnm2.estimates.S_dff})

# %% [markdown]
# ### View movie with the results
# We can inspect the denoised results by reconstructing the movie and playing alongside the original data and the resulting (amplified) residual movie. The denoised movie is saved, as well as a separate movie of the motion corrected data.

# %%
cnm2.estimates.play_movie(images, q_max=99.9, gain_res=1,
                                  magnification=1,
                                  frame_range=slice(0, 1000),
                                  bpx=border_to_0,
                                  display=True,
                                  include_bck=True)

# reconstruct denoised movie
# denoised = cm.movie(cnm2.estimates.A.dot(cnm2.estimates.C) + \
#                    cnm2.estimates.b.dot(cnm2.estimates.f)).reshape(dims + (-1,), order='F').transpose([2, 0, 1])
# save motion corrected movie
# denoised.save(savedir + 'denoised_movie.tif')

# %% [markdown]
# ### Stop cluster and clean up log files

# %%
#%% STOP CLUSTER and clean up log files
cm.stop_server(dview=dview)
log_files = glob.glob('*_LOG_*')
for log_file in log_files:
    os.remove(log_file)
