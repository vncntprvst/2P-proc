# %% [markdown]
# ## MCORR AND CNMF
# **Analysis of riboL1-GCaMP8m responses imaged with 16x objective at zoom 1.4x over 765x765 pixels, 20fps**

# %% [markdown]
# #### Define parameters

# %%
# Paths

import json
from pathlib import Path
data_path = [Path('D:/Data/2P/Scnn1aAi14_B2M0/04192024/TSeries-04192024-1446-004')]
export_path = Path('H:/Analysis/2P/Scnn1aAi14_B2M0/04192024/run4/mesmerize/')

# Motion correction parameters

params_mcorr = \
{
  'main':
    {
        'strides': [48, 48],
        'overlaps': [24, 24],
        'max_shifts': [12, 12],
        'max_deviation_rigid': 6,
        'border_nan': 'copy',
        'pw_rigid': True,
        'gSig_filt': None
    },
}

# CNMF parameters
params_cnmf =\
{
    'main': # indicates that these are the "main" params for the CNMF algo
        {
            'fr': 20, # framerate, very important!
            'p': 1,
            'nb': 1,
            'merge_thr': 0.8,
            'rf': 20,
            'stride': 10, # "stride" for cnmf, "strides" for mcorr
            'K': 6,
            'gSig': [6, 6],
            'ssub': 1,
            'tsub': 1,
            'method_init': 'greedy_roi',
            'min_SNR': 2.5,
            'SNR_lowest':  1.5,
            'rval_thr': 0.85,
            'rval_lowest': 0.2,
            'use_cnn': True,
            'min_cnn_thr': 0.95,
            'cnn_lowest': 0.2,
            'decay_time': 0.15,
        },
    'refit': True, # If `True`, run a second iteration of CNMF
}

# Extra parameters
params_extra = \
    {
        'cleanup': False # If `True`, run cleanup after CNMF, i.e., delete all df data
    }

# Concatenate the two dictionaries
params = {'params_mcorr': params_mcorr, 'params_cnmf': params_cnmf, 'params_extra': params_extra, 'export_path': str(export_path)}
# params['export_path'] = str(export_path)

# # Add z correction parameters
# zstack_path="D:/Data/2P/C57_O1M2/10022023/ZSeries-10022023-1300-004"
# z_params_path="D:/Code/Analysis_2P/Mesmerize/parameters/params_zshift_C57_O1M2.json"

# # Load z-corr parameters
# with open(z_params_path) as f:
#     zstack_params = json.load(f)
                    
# # Add export_path, zstack_path, zstack_params to params dictionary
# params['zstack_path'] = str(zstack_path)
# params['z_params'] = zstack_params

# # Override value in z_params, just in case: don't run pbp zcorr, just do z-correlation 
# params['z_params']['do_zcorr'] = False

print(params)
# Out:
# {'params_mcorr': {'main': {'strides': [48, 48], 'overlaps': [24, 24], 'max_shifts': [12, 12], 'max_deviation_rigid': 6, 'border_nan': 'copy', 'pw_rigid': True, 'gSig_filt': None}}, 'params_cnmf': {'main': {'fr': 20, 'p': 1, 'nb': 1, 'merge_thr': 0.8, 'rf': 20, 'stride': 10, 'K': 6, 'gSig': [6, 6], 'ssub': 1, 'tsub': 1, 'method_init': 'greedy_roi', 'min_SNR': 2.5, 'SNR_lowest': 1.5, 'rval_thr': 0.85, 'rval_lowest': 0.2, 'use_cnn': True, 'min_cnn_thr': 0.95, 'cnn_lowest': 0.2, 'decay_time': 0.15}, 'refit': True}, 'params_extra': {'cleanup': False}, 'export_path': 'H:\\Analysis\\2P\\Scnn1aAi14_B2M0\\04192024\\run4\\mesmerize'}

# %% [markdown]
# #### Run MCORR and CNMF

# %%
import pipeline_mcorr_cnmf as preproc
_ , batch_path = preproc.run_mcorr_cnmf(data_path, params)
# Out:
# Starting run_mcorr_cnmf pipeline.
# Loading and concatenating data from [WindowsPath('D:/Data/2P/Scnn1aAi14_B2M0/04192024/TSeries-04192024-1446-004')].
# Found 1600 files to concatenate.
# Saving concatenated file to directory: H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize
# Input files are single tiff
# Images are uint16 with range (0, 4095).
# Concatenated 1600 files to multi-page TIFF H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\cat_tiff_mpt.tiff.
# Done with concatenation.
# Memory needed to load file: 1.74 GB
# Memory available: 92.05 GB
# Images are uint16 with range 0 - 4095.
# Set -r flag to False to disable conversion from uint12 to uint16.
# Memory needed to scale array, to convert to uint16: 27.91 GB
# Total memory needed: 29.66 GB
# Converted data range: 0 - 65535
# Removed H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\cat_tiff_mpt.tiff
# Error converting to BigTIFF: [Errno 22] Invalid argument: 'H:\\Analysis\\2P\\Scnn1aAi14_B2M0\\04192024\\run4\\mesmerize\\cat_tiff_bt.tiff'
# Concatenated 1600 files to BigTIFF H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\cat_tiff_bt.tiff.
# Concatenation completed in 10.68 seconds.
# Concatenation completed in 00:00:10.
# Concatenated movie path: H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\cat_tiff_bt.tiff.
# Creating batch H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\batch_20240521-151646.pickle.
# Running batch item 0, id 589f8b60-0b42-447a-b384-8fbafec13918, algo mcorr.
# Running 589f8b60-0b42-447a-b384-8fbafec13918 with local backend
# starting mc
# The local backend is an alias for the multiprocessing backend, and the alias may be removed in some future version of Caiman
# mc finished successfully!
# computing projections
# Computing correlation image
# finished computing correlation image
# Batch completed for motion correction. Results saved to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\batch_20240521-151646.pickle.
# mcorr completed in 00:03:07.
# mcorr movie path: H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\589f8b60-0b42-447a-b384-8fbafec13918\589f8b60-0b42-447a-b384-8fbafec13918-cat_tiff_bt_els__d1_765_d2_765_d3_1_order_F_frames_1600.mmap
# Projections recomputed and saved to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\589f8b60-0b42-447a-b384-8fbafec13918.
# Renaming file H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\589f8b60-0b42-447a-b384-8fbafec13918\589f8b60-0b42-447a-b384-8fbafec13918-cat_tiff_bt_els__d1_765_d2_765_d3_1_order_F_frames_1600.mmap to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\589f8b60-0b42-447a-b384-8fbafec13918\original_589f8b60-0b42-447a-b384-8fbafec13918-cat_tiff_bt_els__d1_765_d2_765_d3_1_order_F_frames_1600.mmap.
# Saved 8 bit motion corrected movie to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\mcorr_u8.tiff.
# Saved original vs motion corrected movie to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\compare_og_mcorr.mp4.
# Running batch item 1, id 55f19a2b-1d43-42f2-9f6b-867d6f287c83, algo cnmf.
# Running 55f19a2b-1d43-42f2-9f6b-867d6f287c83 with local backend
# ************************************************************************
#
# Starting CNMF item:
# algo                                                             cnmf
# item_name                                                 cat_tiff_bt
# input_movie_path    589f8b60-0b42-447a-b384-8fbafec13918\589f8b60-...
# params              {'main': {'fr': 20, 'p': 1, 'nb': 1, 'merge_th...
# outputs                                                          None
# added_time                                        2024-05-21T15:20:50
# ran_time                                                         None
# algo_duration                                                    None
# comments                                                         None
# uuid                             55f19a2b-1d43-42f2-9f6b-867d6f287c83
# Name: 1, dtype: object
# With params:{'main': {'fr': 20, 'p': 1, 'nb': 1, 'merge_thr': 0.8, 'rf': 20, 'stride': 10, 'K': 6, 'gSig': (6, 6), 'ssub': 1, 'tsub': 1, 'method_init': 'greedy_roi', 'min_SNR': 2.5, 'SNR_lowest': 1.5, 'rval_thr': 0.85, 'rval_lowest': 0.2, 'use_cnn': True, 'min_cnn_thr': 0.95, 'cnn_lowest': 0.2, 'decay_time': 0.15}, 'refit': True}
# WARNING:caiman.cluster:The local backend is an alias for the multiprocessing backend, and the alias may be removed in some future version of Caiman
# making memmap
# WARNING:caiman.cluster:The local backend is an alias for the multiprocessing backend, and the alias may be removed in some future version of Caiman
# performing CNMF
# fitting images
# refitting
# performing eval
# GPU run not requested, disabling use of GPUs
# USING MODEL (keras API): C:\Users\pseud\caiman_data\model\cnn_model.json
# 93/93 [==============================] - 1s 9ms/step
# WARNING:root:inf values detected for trace SNR in [ 106  135  188  215  216  233  427  428  430  432  433  434  512  514
#   553  971 2118 2121 2209 2278 2281 2383 2384 2475 2542 2625 2853]. Changing their value to max SNR value.
# max SNR value: 34.4643997653512
# Batch completed for CNMF. Results saved to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\batch_20240521-151646.pickle.
# Saved parameters to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\caiman_params.json.
# Calculating estimates.F_dff
# C:\Users\pseud\miniforge3\envs\mescore\lib\site-packages\caiman\utils\stats.py:268: RuntimeWarning: divide by zero encountered in divide
#   density = fftpack.idct(SmDCTData, norm=None) * N / R
# C:\Users\pseud\miniforge3\envs\mescore\lib\site-packages\numpy\lib\function_base.py:4979: RuntimeWarning: invalid value encountered in add
#   ret = (d * (y[tuple(slice1)] + y[tuple(slice2)]) / 2.0).sum(axis)
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# Saved mean_intensity_template.npy to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize.
# Saved results to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize/results_caiman.mat.
# WARNING:root:Keeping batch files associated to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\batch_20240521-151646.pickle.
# Saved components movie to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize/components_movie.mp4
# Keeping batch files associated to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\batch_20240521-151646.pickle.
# Pipeline completed. Results saved to H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize.

# %% [markdown]
# ### Load outputs

# %%
# If cleanup was set to false in the params, you can load the batch file into Mesmerize:
# batch_path=Path('H:/Analysis/2P/Scnn1aAi14_A2M0/12132023/run3/mesmerize/batch_20240105-235525.pickle')
# batch_path=Path('H:/Analysis/2P/Scnn1aAi14_A2M0/12142023/run2/mesmerize/batch_20240409-144602.pickle')
print(batch_path)
if params['params_extra']['cleanup'] == False:
    import mesmerize_core as mc
    df = mc.load_batch(batch_path)
# Out:
# H:\Analysis\2P\Scnn1aAi14_B2M0\04192024\run4\mesmerize\batch_20240521-151646.pickle

# %% [markdown]
# ### Visualize with fastplotlib

# %%
import fastplotlib as fpl
cnmf_index = 1
rcm = df.iloc[cnmf_index].cnmf.get_rcm()
rcb = df.iloc[cnmf_index].cnmf.get_rcb()
residuals = df.iloc[cnmf_index].cnmf.get_residuals()
input_movie = df.iloc[cnmf_index].caiman.get_input_movie()

iw_rcm = fpl.ImageWidget(
    data=[input_movie, rcm, rcb, residuals], 
    grid_plot_kwargs={"size": (800, 600)}, 
    cmap="gnuplot2"
)
iw_rcm.show()
# Out:
# RFBOutputContext()
# JupyterOutputContext(children=(JupyterWgpuCanvas(css_height='600px', css_width='800px'), IpywidgetToolBar(chil…

# %%
iw_rcm.close()

# %% [markdown]
# ### Visualize with `mesmerize-viz`

# %%
print(f"Num accepted/rejected: {len(df.iloc[-1].cnmf.get_good_components())}, {len(df.iloc[-1].cnmf.get_bad_components())}")
# Out:
# Num accepted/rejected: 457, 2498

# %%
import mesmerize_viz
viz_simple = df.cnmf.viz(
    image_data_options=["max"],
)
viz_simple.show(sidecar=True)
# viz_simple.show()
viz_simple.image_widget.cmap = "gray"

# %%
viz_simple.close()

# %% [markdown]
# #### Clean up export folder: stop/restart notebook, then run first and last cells

# %%
import pipeline_mcorr_cnmf as preproc
batch_path=Path('H:/Analysis/2P/C57_O1M2/10022023/run7/mesmerize/batch_20231230-135733.pickle')
preproc.cleanup_files(batch_path, export_path)
