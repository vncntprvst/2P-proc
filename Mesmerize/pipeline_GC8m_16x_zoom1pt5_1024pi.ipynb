# %% [markdown]
# ## MCORR AND CNMF
# **Analysis of riboL1-GCaMP8m responses imaged with 16x objective at zoom 1.5x over 1024x1024 pixels, 15fps**

# %% [markdown]
# #### Define parameters

# %%
# Paths

from pathlib import Path
data_path = [Path('D:/Data/2P/Scnn1aAi14_A2M0/12272023/TSeries-12272023-1432-006')]
export_path = Path('H:/Analysis/2P/Scnn1aAi14_A2M0/12272023/run6/mesmerize/')

# Motion correction parameters

params_mcorr = \
{
  'main':
    {
        'strides': [72, 72],
        'overlaps': [48, 48],
        'max_shifts': [32, 32],
        'max_deviation_rigid': 24,
        'border_nan': 'copy',
        'pw_rigid': True,
        'gSig_filt': None
    },
}

# CNMF parameters
params_cnmf =\
{
    'main': # indicates that these are the "main" params for the CNMF algo
        {
            'fr': 15, # framerate, very important!
            'p': 1,
            'nb': 2,
            'merge_thr': 0.8,
            'rf': 30,
            'stride': 15, # "stride" for cnmf, "strides" for mcorr
            'K': 6,
            'gSig': [8, 8],
            'ssub': 1,
            'tsub': 1,
            'method_init': 'greedy_roi',
            'min_SNR': 2.0,
            'SNR_lowest':  0.5,
            'rval_thr': 0.85,
            'rval_lowest': -0.1,
            'use_cnn': True,
            'min_cnn_thr': 0.95,
            'cnn_lowest': 0.2,
            'decay_time': 0.15,
        },
    'refit': True, # If `True`, run a second iteration of CNMF
}

# Extra parameters
params_extra = \
    {
        'cleanup': False # If `True`, run cleanup after CNMF, i.e., delete all df data
    }

# Concatenate the two dictionaries
params = {'params_mcorr': params_mcorr, 'params_cnmf': params_cnmf, 'params_extra': params_extra}
print(params)
# Out:
# {'params_mcorr': {'main': {'strides': [72, 72], 'overlaps': [48, 48], 'max_shifts': [32, 32], 'max_deviation_rigid': 24, 'border_nan': 'copy', 'pw_rigid': True, 'gSig_filt': None}}, 'params_cnmf': {'main': {'fr': 15, 'p': 1, 'nb': 2, 'merge_thr': 0.8, 'rf': 30, 'stride': 15, 'K': 6, 'gSig': [8, 8], 'ssub': 1, 'tsub': 1, 'method_init': 'greedy_roi', 'min_SNR': 2.0, 'SNR_lowest': 0.5, 'rval_thr': 0.85, 'rval_lowest': -0.1, 'use_cnn': True, 'min_cnn_thr': 0.95, 'cnn_lowest': 0.2, 'decay_time': 0.15}, 'refit': True}, 'params_extra': {'cleanup': False}}

# %% [markdown]
# #### Run MCORR and CNMF

# %%
import pipeline_mcorr_cnmf as preproc
_ , batch_path = preproc.run_mcorr_cnmf(data_path, params, export_path)
# Out:
# Starting run_mcorr_cnmf pipeline.
# Loading and concatenating data from [WindowsPath('D:/Data/2P/Scnn1aAi14_A2M0/12272023/TSeries-12272023-1432-006')].
# Found 1200 files to concatenate.
# Saving concatenated file to directory: H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize
# Images are uint16 with range (0, 4095).
# Concatenated 1200 files to multi-page TIFF H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize\cat_tiff_mpt.tiff.
# Images are uint16 with range 0 - 4095.
# Set -r flag to False to disable conversion from uint12 to uint16.
# Converted data range: 0 - 65535
# Removed H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize\cat_tiff_mpt.tiff
# Concatenated 1200 files to BigTIFF H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize\cat_tiff_bt.tiff.
# Concatenation completed in 13.70 seconds.
# Concatenated movie path: H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize\cat_tiff_bt.tiff.
# Creating batch H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize\batch_20240107-171714.pickle.
# Running batch item 0, id ff7f29ec-a00c-4c9d-904b-6537fb30be0e, algo mcorr.
# Running ff7f29ec-a00c-4c9d-904b-6537fb30be0e with local backend
# starting mc
# mc finished successfully!
# computing projections
# Computing correlation image
# finished computing correlation image
# Running a7e7fff7-4168-4883-8796-01174554c69b with local backend
# ************************************************************************
#
# Starting CNMF item:
# algo                                                             cnmf
# item_name                                                 cat_tiff_bt
# input_movie_path    ff7f29ec-a00c-4c9d-904b-6537fb30be0e\ff7f29ec-...
# params              {'main': {'fr': 15, 'p': 1, 'nb': 2, 'merge_th...
# outputs                                                          None
# added_time                                        2024-01-07T17:21:50
# ran_time                                                         None
# algo_duration                                                    None
# comments                                                         None
# uuid                             a7e7fff7-4168-4883-8796-01174554c69b
# Name: 1, dtype: object
# With params:{'main': {'fr': 15, 'p': 1, 'nb': 2, 'merge_thr': 0.8, 'rf': 30, 'stride': 15, 'K': 6, 'gSig': (8, 8), 'ssub': 1, 'tsub': 1, 'method_init': 'greedy_roi', 'min_SNR': 2.0, 'SNR_lowest': 0.5, 'rval_thr': 0.85, 'rval_lowest': -0.1, 'use_cnn': True, 'min_cnn_thr': 0.95, 'cnn_lowest': 0.2, 'decay_time': 0.15}, 'refit': True}
# making memmap
# performing CNMF
# fitting images
# refitting
# performing eval
# GPU run not requested, disabling use of GPUs
# USING MODEL (keras API): C:\Users\pseud\caiman_data\model\cnn_model.json
# 69/69 [==============================] - 1s 9ms/step
# C:\Users\pseud\miniforge3\envs\mescore\lib\site-packages\caiman\utils\stats.py:281: RuntimeWarning: divide by zero encountered in divide
#   density = fftpack.idct(SmDCTData, norm=None) * N / R
# C:\Users\pseud\miniforge3\envs\mescore\lib\site-packages\numpy\lib\function_base.py:4978: RuntimeWarning: invalid value encountered in add
#   ret = (d * (y[tuple(slice1)] + y[tuple(slice2)]) / 2.0).sum(axis)
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:NaN percentile computed. Reverting to median.
# WARNING:root:Keeping batch files associated to H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize\batch_20240107-171714.pickle.

# %% [markdown]
# ### Load outputs

# %%
# If cleanup was set to false in the params, you can load the batch file into Mesmerize:
# batch_path=Path('H:/Analysis/2P/Scnn1aAi14_A2M0/12132023/run3/mesmerize/batch_20240105-235525.pickle')
print(batch_path)
if params['params_extra']['cleanup'] == False:
    import mesmerize_core as mc
    df = mc.load_batch(batch_path)
# Out:
# H:\Analysis\2P\Scnn1aAi14_A2M0\12272023\run6\mesmerize\batch_20240107-171714.pickle

# %% [markdown]
# ### Visualize with fastplotlib

# %%
import fastplotlib as fpl
cnmf_index = 1
rcm = df.iloc[cnmf_index].cnmf.get_rcm()
rcb = df.iloc[cnmf_index].cnmf.get_rcb()
residuals = df.iloc[cnmf_index].cnmf.get_residuals()
input_movie = df.iloc[cnmf_index].caiman.get_input_movie()

iw_rcm = fpl.ImageWidget(
    data=[input_movie, rcm, rcb, residuals], 
    grid_plot_kwargs={"size": (800, 600)}, 
    cmap="gnuplot2"
)
iw_rcm.show()
# Out:
# RFBOutputContext()
# WARNING:wgpu:	EGL surface: -srgb
# WARNING:wgpu:No config found!
# WARNING:wgpu:EGL says it can present to the window but not natively
# C:\Users\pseud\miniforge3\envs\mescore\lib\site-packages\fastplotlib\graphics\_features\_base.py:34: UserWarning: converting float64 array to float32
#   warn(f"converting {array.dtype} array to float32")
# JupyterOutputContext(children=(JupyterWgpuCanvas(css_height='600px', css_width='800px'), IpywidgetToolBar(chil…

# %%
iw_rcm.close()

# %% [markdown]
# ### Visualize with `mesmerize-viz`

# %%
print(f"Num accepted/rejected: {len(df.iloc[-1].cnmf.get_good_components())}, {len(df.iloc[-1].cnmf.get_bad_components())}")
# Out:
# Num accepted/rejected: 479, 1699

# %%
import mesmerize_viz
viz_simple = df.cnmf.viz(
    image_data_options=["max"],
)
viz_simple.show(sidecar=True)
# viz_simple.show()
viz_simple.image_widget.cmap = "gray"
# Out:
# C:\Users\pseud\miniforge3\envs\mescore\lib\site-packages\ipydatagrid\datagrid.py:460: UserWarning: Index name of 'index' is not round-trippable.
#   schema = pd.io.json.build_table_schema(dataframe)
# RFBOutputContext()
# RFBOutputContext()
# C:\Users\pseud\miniforge3\envs\mescore\lib\site-packages\fastplotlib\graphics\_features\_base.py:34: UserWarning: converting float64 array to float32
#   warn(f"converting {array.dtype} array to float32")
# RFBOutputContext()

# %%
viz_simple.close()

# %% [markdown]
# #### Clean up export folder: stop/restart notebook, then run first and last cells

# %%
import pipeline_mcorr_cnmf as preproc
batch_path=Path('H:/Analysis/2P/C57_O1M2/10022023/run7/mesmerize/batch_20231230-135733.pickle')
preproc.cleanup_files(batch_path, export_path)
